# %%
from stdmodandoption import *
import plot_setup as PS
from calmassloading import calmassloading
dirneed = ['bwsmclr','bwsmclrdc27','bwsmclrdc28','bwsmclrdc29']
Nsnaplist = range(0,501,10)
fig, ax = PS.setupfig(nrows=1, ncols=1,sharex=True,sharey=True)

for runtodo in dirneed:
    data = calmassloading([runtodo],Nsnaplist,avesnap=0)
    ax.plot(Nsnaplist,data['mll'])

PS.miscsetup(ax,logx=0,logy=1,legendneed=1,labfs=22,legfs=12)
# Out:
# rundir smc_lr_2_21
# maindir oasis/bw/smc
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_000.hdf5
# npart_file:  [ 328700 1000000   57000    4200    1300       1]
# npart_total: [ 328700 1000000   57000    4200    1300       1]
# flag_cooling 1
# rundir smc_lr_2_21
# the_snapdir /home/tkc004/oasis/bw/smc/smc_lr_2_21//output/
# Nsnapstring 000
# havecr 0
# withinRv 1
# cosmo 0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_000.hdf5
# npart_file:  [ 328700 1000000   57000    4200    1300       1]
# npart_total: [ 328700 1000000   57000    4200    1300       1]
# flag_cooling 1
# timeneed 0.0
# np.median(vr) 4.930102458510706
# np.sum(Gmass) 0.0136274253982549
# runtodo bwsmclr
# dc 0
# Gmass 0.0136274253982549
# SFR 0.0
# Rvir 63
# rundir smc_lr_2_21
# maindir oasis/bw/smc
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_010.hdf5
# ...
