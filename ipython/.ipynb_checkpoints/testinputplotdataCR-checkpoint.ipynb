# %%
import collections
from importplotfunctionsCR import *
from inputplotdataCR import inputplotdict
plotlist = ['figCRenergies_bwsmclrdc28strpts']
for plotneed in plotlist:
    inputplotdict[plotneed]['_plotfunction'](inputplotdict[plotneed])
# Out:
# wanted cratmult
# fmeat bwsmclrdc28strpts
# runtodo ['bwsmclrdc28strpts']
# startno 0
# Nsnap 501
# snapsep 10
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 000
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_000.hdf5
# npart_file:  [ 328807 1000000   57000    4200    1193       1]
# npart_total: [ 328807 1000000   57000    4200    1193       1]
# flag_cooling 1
# cregy 0.0
# cregyp 0.0
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 010
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_010.hdf5
# npart_file:  [ 328736 1000000   57000    4200    1264       1]
# npart_total: [ 328736 1000000   57000    4200    1264       1]
# flag_cooling 1
# cregy 7.703731447042894e+52
# cregyp -2.3234888824661485e+55
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 020
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_020.hdf5
# npart_file:  [ 328696 1000000   57000    4200    1304       1]
# npart_total: [ 328696 1000000   57000    4200    1304       1]
# flag_cooling 1
# cregy 2.6427970698317886e+53
# cregyp -1.0130842387720828e+56
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 030
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_030.hdf5
# npart_file:  [ 328616 1000000   57000    4200    1384       1]
# npart_total: [ 328616 1000000   57000    4200    1384       1]
# flag_cooling 1
# cregy 4.266249756257339e+53
# cregyp -1.903151981871377e+56
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 040
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_040.hdf5
# npart_file:  [ 328537 1000000   57000    4200    1463       1]
# npart_total: [ 328537 1000000   57000    4200    1463       1]
# flag_cooling 1
# cregy 7.18607704923655e+53
# cregyp -3.315896943500914e+56
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 050
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_050.hdf5
# npart_file:  [ 328351 1000000   57000    4200    1649       1]
# npart_total: [ 328351 1000000   57000    4200    1649       1]
# flag_cooling 1
# cregy 1.0508221406445403e+54
# cregyp -4.939872230498252e+56
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 060
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_060.hdf5
# npart_file:  [ 328177 1000000   57000    4200    1823       1]
# npart_total: [ 328177 1000000   57000    4200    1823       1]
# flag_cooling 1
# cregy 1.5483178615710655e+54
# cregyp -7.1411156453993285e+56
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 070
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_070.hdf5
# npart_file:  [ 328097 1000000   57000    4200    1903       1]
# npart_total: [ 328097 1000000   57000    4200    1903       1]
# flag_cooling 1
# cregy 2.1083773043681196e+54
# cregyp -9.951843855372661e+56
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 080
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_080.hdf5
# npart_file:  [ 328031 1000000   57000    4200    1969       1]
# npart_total: [ 328031 1000000   57000    4200    1969       1]
# flag_cooling 1
# cregy 2.5706586279858648e+54
# cregyp -1.2756552186639602e+57
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 090
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_090.hdf5
# npart_file:  [ 327924 1000000   57000    4200    2076       1]
# npart_total: [ 327924 1000000   57000    4200    2076       1]
# flag_cooling 1
# cregy 2.8675574656213166e+54
# cregyp -1.5253980758637605e+57
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 100
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_100.hdf5
# npart_file:  [ 327858 1000000   57000    4200    2142       1]
# npart_total: [ 327858 1000000   57000    4200    2142       1]
# flag_cooling 1
# cregy 3.041896767329683e+54
# cregyp -1.7203559544327378e+57
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 110
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output//snapshot_110.hdf5
# npart_file:  [ 327830 1000000   57000    4200    2170       1]
# npart_total: [ 327830 1000000   57000    4200    2170       1]
# flag_cooling 1
# cregy 3.1490185774671456e+54
# cregyp -1.859041035392941e+57
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 120
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 130
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 140
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 150
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 160
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 170
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 180
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 190
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 200
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 210
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 220
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 230
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 240
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 250
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 260
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 270
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 280
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 290
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 300
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 310
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 320
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 330
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 340
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 350
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 360
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 370
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 380
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 390
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 400
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 410
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 420
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 430
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 440
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 450
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 460
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 470
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 480
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 490
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir smc_cr_lr_dc28_2_21_str_ll_va_evepts
# the_snapdir /home/tkc004/oasis/bw/smc/smc_cr_lr_dc28_2_21_str_ll_va_evepts//output/
# Nsnapstring 500
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# filename /home/tkc004//samsonprogramdata/CRplot/cratmult/bwsmclrdc28strpts_time.pdf
