# %%
from stdmodandoption import *
import plot_setup as PS
import collections
from calrhog import calrhog


def main():
    startno=450
    Nsnap=501
    snapsep=10
    wanted='rhog'
    dirdict = collections.defaultdict(dict)
    keylist=['plot1','plot2','plot3']
    dirdict['plot2']=['bwsbclr','bwsbclrdc27','bwsbclrdc28','bwsbclrdc29']
    dirdict['plot3']=['bwmwmr','bwmwmrdc27','bwmwmrdc28','bwmwmrdc29']
    dirdict['plot1']=['bwsmclr','bwsmclrdc27','bwsmclrdc28','bwsmclrdc29']
    noplots=len(dirdict.keys())
    fig, ax = PS.setupfig(nrows=noplots, ncols=1,sharex=True,sharey=False)
    fmeat=''
    nokey = len(keylist)
    for i, key in enumerate(keylist):
        items=dirdict[key]
        for j, runtodo in enumerate(items):
            print 'runtodo', runtodo
            plotdict = calrhog(runtodo,wanted,startno,Nsnap,snapsep,fmeat)
            xlab = plotdict[wanted]['xlab'];
            ylab = plotdict[wanted]['ylab'];
            ptitle = plotdict[wanted]['ptitle']
            filename = plotdict[wanted]['filename'];
            for k,inkey in enumerate(plotdict[wanted]['xnl']):
                xnl = plotdict[wanted]['xnl'][inkey];
                ynl = plotdict[wanted]['ynl'][inkey];
                labelneed = plotdict[wanted]['labelneed'];
                color = plotdict[wanted]['color'];
                lsn = plotdict[wanted]['lsn'];
                lw = plotdict[wanted]['lw'][inkey];
                marker = plotdict[wanted]['marker'][inkey];
                linelabel = plotdict[wanted]['linelab'][inkey];
                legendneed = plotdict[wanted]['legendneed']
                if i==0 and j==1: 
                    label = linelabel
                elif i==1 and k==0:
                    label = labelneed
                else:
                    label = '_nolegend_' 
                if nokey==1:
                    ax.plot(xnl,ynl,label=label,lw=lw,ls=lsn,color=color,marker=marker)
                else:
                    ax[i].plot(xnl,ynl,label=label,lw=lw,ls=lsn,color=color,marker=marker)
        if i<noplots-1: xlab=''
        if nokey==1:
            ax.text(0.25, 0.95, ptitle, horizontalalignment='center',
        verticalalignment='center', transform=ax[i].transAxes,fontsize=22)            
        else:
            ax[i].text(0.25, 0.95, ptitle, horizontalalignment='center',
        verticalalignment='center', transform=ax[i].transAxes,fontsize=22)
        if nokey==1:
            PS.miscsetup(ax,logx=0,logy=1,xlab=xlab,ylab=ylab,legendneed=legendneed,labfs=22,legfs=12)
        else:
            PS.miscsetup(ax[i],logx=0,logy=1,xlab=xlab,ylab=ylab,legendneed=legendneed,labfs=22,legfs=12)        
    PS.finishsave(plt,filename)


        
if __name__ == '__main__':
    main()
# Out:
# runtodo bwsmclr
# runtodo bwsmclr
# rundir smc_lr_2_21
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 6.102786109295184 6.3607066100745415 -0.9482728724033783
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.071851089408156 -0.23354045328499903 0.16801514097083226
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.4614110462780652 -1.351245321246135 -0.5604026135889013
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.1102777802110788 0.35831437750883477 -0.05693643474239744
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_450.hdf5
# npart_file:  [ 326693 1000000   57000    4200    3307       1]
# npart_total: [ 326693 1000000   57000    4200    3307       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.9282240061502376 1.476772844515716 -0.5262231003995665
# diskr, diskh 10 1.0
# mdisktot 1.1873829524494742e+42
# mdisktot 1.5633207427152935e+42
# mdisktot 1.580686481530585e+42
# Pmtot 2.7061726256202074e+40
# Pmtot 1.4517102924524358e+43
# Pmtot -9.888512101701169e+37
# Pmtot -3.3834119092670427e+41
# Pmtot 1.0449423022990268e+38
# Pmtot 8.2080764830774725e+40
# Pmtot 2.5694576684818335e+43
# Pmtot 4.640999988280913e+37
# Pmtot -3.509831339962262e+41
# Pmtot 1.1517214046207918e+38
# Pmtot 2.7000718104273544e+41
# Pmtot 3.479863965991566e+43
# Pmtot 3.698150135076257e+38
# Pmtot -3.499591612689673e+41
# Pmtot 1.1517214046207918e+38
# Pmtot 6.051998534155862e+41
# Pmtot 4.09665844088825e+43
# Pmtot 4.82256929566065e+38
# Pmtot -3.4906706874851864e+41
# Pmtot 1.1517214046207918e+38
# Pmtot 7.197729730905312e+41
# Pmtot 4.60629315299521e+43
# Pmtot 4.82256929566065e+38
# Pmtot -3.485312021651996e+41
# Pmtot 1.1517214046207918e+38
# Pmtot 7.908382085190724e+41
# Pmtot 4.995536080790234e+43
# Pmtot 4.82256929566065e+38
# Pmtot -3.484650478514056e+41
# Pmtot 1.2068808440560034e+38
# Pmtot 8.469400086477837e+41
# Pmtot 5.231578271170306e+43
# Pmtot 4.82256929566065e+38
# Pmtot -3.484584178514223e+41
# Pmtot 1.2068808440560034e+38
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 3.5262856224265784 5.8732332212493406 0.14433337457499495
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.004617424601344114 -0.16902182485869982 0.1016712624587246
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.9632682880113511 -1.2653419568296609 -0.7683329515536683
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.56073756549151 0.09761943903655179 -0.2700137103657207
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_460.hdf5
# npart_file:  [ 326677 1000000   57000    4200    3323       1]
# npart_total: [ 326677 1000000   57000    4200    3323       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.6970570464189807 0.6601467756377384 -0.3247913127505418
# diskr, diskh 10 1.0
# mdisktot 1.1918783656739975e+42
# mdisktot 1.5678264720089626e+42
# mdisktot 1.5852499809427353e+42
# Pmtot 2.798818615391346e+40
# Pmtot 1.453088127935978e+43
# Pmtot -3.909584235233371e+37
# Pmtot -3.3731681940136158e+41
# Pmtot 1.0576521712834936e+38
# Pmtot 8.466165525275094e+40
# Pmtot 2.574044994178334e+43
# Pmtot 4.631940648131159e+37
# Pmtot -3.509748648828833e+41
# Pmtot 1.1162251936070965e+38
# Pmtot 2.6717354049235366e+41
# Pmtot 3.483117544903316e+43
# Pmtot 3.434717819319907e+38
# Pmtot -3.4995740234314184e+41
# Pmtot 1.1162251936070965e+38
# Pmtot 5.9503829790456026e+41
# Pmtot 4.097201012774961e+43
# Pmtot 4.5591369799043006e+38
# Pmtot -3.49072136292576e+41
# Pmtot 1.1162251936070965e+38
# Pmtot 7.139189970817864e+41
# Pmtot 4.60005243921927e+43
# Pmtot 4.5591369799043006e+38
# Pmtot -3.485429053312262e+41
# Pmtot 1.1162251936070965e+38
# Pmtot 7.84400728401939e+41
# Pmtot 4.987126561394263e+43
# Pmtot 4.5591369799043006e+38
# Pmtot -3.484766083970578e+41
# Pmtot 1.1713846330423082e+38
# Pmtot 8.401966335242153e+41
# Pmtot 5.227183349411414e+43
# Pmtot 4.5591369799043006e+38
# Pmtot -3.484633514689739e+41
# Pmtot 1.1713846330423082e+38
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.194485807217422 4.97333683844086 1.49626065538188
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.09323802372206504 -0.17483169261425238 0.07671693805722221
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.4019811227505001 -1.0660862886838445 -0.8260373301193907
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.0049590979267579 -0.037056193046083444 -0.38230264759071597
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_470.hdf5
# npart_file:  [ 326635 1000000   57000    4200    3365       1]
# npart_total: [ 326635 1000000   57000    4200    3365       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.8578444230972777 -0.7470826222950046 -0.3194347630991735
# diskr, diskh 10 1.0
# mdisktot 1.1949930469708046e+42
# mdisktot 1.5709186396184764e+42
# mdisktot 1.588589316331982e+42
# Pmtot 3.006242164906524e+40
# Pmtot 1.4577298355245003e+43
# Pmtot -3.32623542763657e+37
# Pmtot -3.3694192753374245e+41
# Pmtot 9.192161939267842e+37
# Pmtot 8.868073963721783e+40
# Pmtot 2.5779686629254737e+43
# Pmtot 6.602819871148114e+37
# Pmtot -3.509671747334815e+41
# Pmtot 9.777892162503629e+37
# Pmtot 2.6668160298440596e+41
# Pmtot 3.4881934822233927e+43
# Pmtot 3.631833927869837e+38
# Pmtot -3.499489206559761e+41
# Pmtot 9.777892162503629e+37
# Pmtot 5.844936667819633e+41
# Pmtot 4.0991967846665896e+43
# Pmtot 4.623653088787956e+38
# Pmtot -3.490839062265417e+41
# Pmtot 9.777892162503629e+37
# Pmtot 7.09234486470273e+41
# Pmtot 4.59484385414436e+43
# Pmtot 4.623653088787956e+38
# Pmtot -3.4852159878694695e+41
# Pmtot 9.777892162503629e+37
# Pmtot 7.794692432269628e+41
# Pmtot 4.978999317692398e+43
# Pmtot 4.623653088787956e+38
# Pmtot -3.4845530185277855e+41
# Pmtot 1.0329486556855745e+38
# Pmtot 8.345224054700826e+41
# Pmtot 5.222707313043269e+43
# Pmtot 4.623653088787956e+38
# Pmtot -3.4842878492472812e+41
# Pmtot 1.0329486556855745e+38
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.35855152307537796 4.515206598334397 2.739870880376479
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.19987990908702016 -0.11173991087559802 -0.0033037472923926154
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.7212152951072932 -0.8353520671720757 -0.8165354288575722
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.6731717507456885 -0.8352452443743293 -0.33924152517620804
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_480.hdf5
# npart_file:  [ 326517 1000000   57000    4200    3483       1]
# npart_total: [ 326517 1000000   57000    4200    3483       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.0999634121710873 -2.544405361047689 -0.34601958802561816
# diskr, diskh 10 1.0
# mdisktot 1.1960286117093131e+42
# mdisktot 1.5719661718321084e+42
# mdisktot 1.5903477759746787e+42
# Pmtot 3.305489669486292e+40
# Pmtot 1.4593773615324875e+43
# Pmtot -3.31202534197738e+37
# Pmtot -3.370346019740984e+41
# Pmtot 8.560381459943687e+37
# Pmtot 9.44250631468395e+40
# Pmtot 2.5831002136093423e+43
# Pmtot 5.9398198728167425e+37
# Pmtot -3.5092076393990666e+41
# Pmtot 8.560381459943928e+37
# Pmtot 2.6821247685886677e+41
# Pmtot 3.4935753889002055e+43
# Pmtot 3.3707626371016962e+38
# Pmtot -3.499157500709416e+41
# Pmtot 8.560381459943928e+37
# Pmtot 5.753223885271298e+41
# Pmtot 4.102109944520601e+43
# Pmtot 4.362581798019816e+38
# Pmtot -3.491232491044458e+41
# Pmtot 8.560381459943928e+37
# Pmtot 7.061879233038104e+41
# Pmtot 4.589785499724746e+43
# Pmtot 4.362581798019816e+38
# Pmtot -3.485412529851417e+41
# Pmtot 8.560381459943928e+37
# Pmtot 7.763429508035883e+41
# Pmtot 4.971351086348864e+43
# Pmtot 4.362581798019816e+38
# Pmtot -3.4846832605099004e+41
# Pmtot 9.111975854296045e+37
# Pmtot 8.307321402017082e+41
# Pmtot 5.218496869331488e+43
# Pmtot 4.362581798019816e+38
# Pmtot -3.4844180912293954e+41
# Pmtot 9.111975854296045e+37
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.0488578789407104 4.2903872669764755 3.3181417018594583
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.2704286275792545 -0.1311174529048511 -0.046462797030143325
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.9784870206983733 -0.5423290627557997 -0.5642258352789565
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.1012735653973693 -1.1475876601809876 -0.4822307765285519
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_490.hdf5
# npart_file:  [ 326461 1000000   57000    4200    3539       1]
# npart_total: [ 326461 1000000   57000    4200    3539       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.8540970936428673 -2.8467227605985714 -0.5372270574374902
# diskr, diskh 10 1.0
# mdisktot 1.1999040935112187e+42
# mdisktot 1.575851565502429e+42
# mdisktot 1.5945030318742832e+42
# Pmtot 3.3595282191018877e+40
# Pmtot 1.4596776523716312e+43
# Pmtot -2.6442809979516776e+37
# Pmtot -3.373104609266293e+41
# Pmtot 8.953759853099317e+37
# Pmtot 9.78022633780219e+40
# Pmtot 2.5858466460495816e+43
# Pmtot 5.966999984935919e+37
# Pmtot -3.509720739514882e+41
# Pmtot 8.953759853099317e+37
# Pmtot 2.6825950508162173e+41
# Pmtot 3.4979984361644453e+43
# Pmtot 3.1090618421792057e+38
# Pmtot -3.499072435170163e+41
# Pmtot 8.953759853099317e+37
# Pmtot 5.639373597069058e+41
# Pmtot 4.1055927914761573e+43
# Pmtot 4.100881003098099e+38
# Pmtot -3.4913484460194865e+41
# Pmtot 8.953759853099317e+37
# Pmtot 7.005900843085688e+41
# Pmtot 4.585752512310887e+43
# Pmtot 4.100881003098099e+38
# Pmtot -3.485594784826279e+41
# Pmtot 8.953759853099317e+37
# Pmtot 7.708034034289253e+41
# Pmtot 4.964168716305917e+43
# Pmtot 4.100881003098099e+38
# Pmtot -3.484799215484929e+41
# Pmtot 9.505354247451433e+37
# Pmtot 8.245424476658026e+41
# Pmtot 5.214031274413633e+43
# Pmtot 4.100881003098099e+38
# Pmtot -3.484534046204424e+41
# Pmtot 9.505354247451433e+37
# rundir smc_lr_2_21
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -3.940465526379307 3.8600881346371048 3.203620625791395
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.364903921516874 -0.1349321009337558 -0.09474590476096152
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 2.092418797904107 -0.1419205092071419 -0.0035657380105891946
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.2200551554430417 -0.7256847351698533 -0.3828919600588418
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_lr_2_21//output//snapshot_500.hdf5
# npart_file:  [ 326390 1000000   57000    4200    3610       1]
# npart_total: [ 326390 1000000   57000    4200    3610       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.5070092584751598 -2.3445040976214337 -0.09875608779955017
# diskr, diskh 10 1.0
# mdisktot 1.1959052077299257e+42
# mdisktot 1.5718570259917973e+42
# mdisktot 1.5908857047564774e+42
# Pmtot 4.0705266684071533e+40
# Pmtot 1.4622867824450022e+43
# Pmtot -2.632785181161375e+37
# Pmtot -3.376870249283672e+41
# Pmtot 9.421159338743107e+37
# Pmtot 1.0903901887134924e+41
# Pmtot 2.5908075010743564e+43
# Pmtot 6.614101549325746e+37
# Pmtot -3.5103102851530975e+41
# Pmtot 9.421159338743107e+37
# Pmtot 2.765159248985483e+41
# Pmtot 3.5037453534919596e+43
# Pmtot 2.9749102704583123e+38
# Pmtot -3.4988028909499776e+41
# Pmtot 9.421159338743107e+37
# Pmtot 5.603981195906715e+41
# Pmtot 4.1101976249931234e+43
# Pmtot 3.900438080754134e+38
# Pmtot -3.4913426712250585e+41
# Pmtot 9.421159338743107e+37
# Pmtot 7.030365275062366e+41
# Pmtot 4.583654813565949e+43
# Pmtot 3.900438080754134e+38
# Pmtot -3.485719537341771e+41
# Pmtot 9.972753733094981e+37
# Pmtot 7.728180262961866e+41
# Pmtot 4.959388851036207e+43
# Pmtot 3.900438080754134e+38
# Pmtot -3.484857668000589e+41
# Pmtot 9.972753733094981e+37
# Pmtot 8.261659490549837e+41
# Pmtot 5.210272362853351e+43
# Pmtot 3.900438080754134e+38
# Pmtot -3.4845261987202525e+41
# Pmtot 9.972753733094981e+37
# thden [3.72316836e-16 1.41503417e-16 1.09990930e-16 8.54664887e-17
#  9.04788929e-17 8.46131746e-17 4.02228676e-17 0.00000000e+00]
# mtotl [1.42678084e+43 2.55440059e+43 3.48308065e+43 4.12504285e+43
#  4.62947553e+43 5.01921353e+43 5.26930599e+43 0.00000000e+00]
# mdtot 1.588377048568457e+42
# runtodo bwsmclrdc27
# runtodo bwsmclrdc27
# rundir smc_cr_lr_dc27_2_21_M1_c500
# rundir smc_cr_lr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.445701096713962 3.0505973983244234 -0.8484531429021044
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.31098225703453536 -0.03622396020680675 0.13750729939353845
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.4926457246908402 0.3377865287279273 0.23654336057193504
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.42099015089061115 1.0431408571261185 -0.4317267095641657
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# this time 0.44999999925494194
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_450.hdf5
# npart_file:  [ 327178 1000000   57000    4200    2822       1]
# npart_total: [ 327178 1000000   57000    4200    2822       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.8306485839359887 3.590512844969755 -0.3441735525710076
# diskr, diskh 10 1.0
# mdisktot 1.126135023198544e+42
# mdisktot 1.5021629502108677e+42
# mdisktot 1.5170544015800545e+42
# Pmtot 5.081769405172148e+40
# Pmtot 1.4520206871682027e+43
# Pmtot -1.3188889106857088e+38
# Pmtot -3.386643291585759e+41
# Pmtot 3.753998582965258e+37
# Pmtot 1.4764839167350223e+41
# Pmtot 2.5768619974250546e+43
# Pmtot 2.6444294477675177e+37
# Pmtot -3.509828223482541e+41
# Pmtot 4.8797520847756065e+37
# Pmtot 3.599990914500213e+41
# Pmtot 3.485659977213623e+43
# Pmtot 3.364992806075133e+38
# Pmtot -3.5004522502251585e+41
# Pmtot 4.8797520847756065e+37
# Pmtot 6.941178125772373e+41
# Pmtot 4.104629025830391e+43
# Pmtot 4.425677231870321e+38
# Pmtot -3.4914623329968275e+41
# Pmtot 4.8797520847756065e+37
# Pmtot 8.080784778257037e+41
# Pmtot 4.614586751540333e+43
# Pmtot 4.425677231870321e+38
# Pmtot -3.4862342462048735e+41
# Pmtot 4.8797520847756065e+37
# Pmtot 8.759169777096828e+41
# Pmtot 5.003783534534931e+43
# Pmtot 4.425677231870321e+38
# Pmtot -3.485574177440555e+41
# Pmtot 5.431346479127965e+37
# Pmtot 9.290537722569419e+41
# Pmtot 5.238752858305094e+43
# Pmtot 4.425677231870321e+38
# Pmtot -3.4855078774407225e+41
# Pmtot 5.431346479127965e+37
# rundir smc_cr_lr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -3.8874723196674097 2.3418106368337392 -0.37132255445694684
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.3490778164721818 0.05207244233571545 0.0593585381356472
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.4821048626818978 0.5803365080945218 0.18258486444752672
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.33354119028223816 0.7772107838477249 -0.39751672434145646
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# this time 0.4599999999627471
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_460.hdf5
# npart_file:  [ 327161 1000000   57000    4200    2839       1]
# npart_total: [ 327161 1000000   57000    4200    2839       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.3312718268654713 2.1810640311481695 -0.30316856483303384
# diskr, diskh 10 1.0
# mdisktot 1.1339076911277303e+42
# mdisktot 1.5099341268388557e+42
# mdisktot 1.5249099126333035e+42
# Pmtot 5.073485863817492e+40
# Pmtot 1.4542206389203338e+43
# Pmtot -5.959773598794262e+37
# Pmtot -3.3774653231007876e+41
# Pmtot 3.2673297895087466e+37
# Pmtot 1.4806839601431784e+41
# Pmtot 2.5807135834869143e+43
# Pmtot 2.6519999933022736e+37
# Pmtot -3.5101518704857796e+41
# Pmtot 4.404021149298473e+37
# Pmtot 3.526716520025554e+41
# Pmtot 3.489376060362204e+43
# Pmtot 3.2351441255573284e+38
# Pmtot -3.5002488894157235e+41
# Pmtot 4.404021149298473e+37
# Pmtot 6.814145324762154e+41
# Pmtot 4.104520858643652e+43
# Pmtot 4.295828551352516e+38
# Pmtot -3.491656894756425e+41
# Pmtot 4.404021149298473e+37
# Pmtot 7.988820282783293e+41
# Pmtot 4.607747211591424e+43
# Pmtot 4.295828551352516e+38
# Pmtot -3.486165697167527e+41
# Pmtot 4.404021149298473e+37
# Pmtot 8.667603944688813e+41
# Pmtot 4.994619450264553e+43
# Pmtot 4.295828551352516e+38
# Pmtot -3.485570502199297e+41
# Pmtot 4.95561554365059e+37
# Pmtot 9.1945295351227e+41
# Pmtot 5.234122500676589e+43
# Pmtot 4.295828551352516e+38
# Pmtot -3.485437931652169e+41
# Pmtot 4.95561554365059e+37
# rundir smc_cr_lr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -5.010165472543406 1.4990918467561674 -0.05144365867510387
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.4124341843549564 0.10007072290076831 0.07322960699384823
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.273247537394321 0.7717724012883288 0.09024615380890151
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.6001306969795795 0.39854794323771253 -0.22285475728537574
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_470.hdf5
# npart_file:  [ 327154 1000000   57000    4200    2846       1]
# npart_total: [ 327154 1000000   57000    4200    2846       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.554796719063065 0.9945153663049947 0.10088230880892257
# diskr, diskh 10 1.0
# mdisktot 1.1370978889387513e+42
# mdisktot 1.513122087673771e+42
# mdisktot 1.528118464769523e+42
# Pmtot 5.537066678534763e+40
# Pmtot 1.457886581978108e+43
# Pmtot -4.648407781707173e+37
# Pmtot -3.3763381881845707e+41
# Pmtot 2.2683359907206667e+37
# Pmtot 1.531729949442517e+41
# Pmtot 2.584208823038218e+43
# Pmtot 3.3070080091267094e+37
# Pmtot -3.510470234014907e+41
# Pmtot 3.365645804421858e+37
# Pmtot 3.511563362744282e+41
# Pmtot 3.4940176066269175e+43
# Pmtot 3.169565645028564e+38
# Pmtot -3.500427970826085e+41
# Pmtot 3.365645804421858e+37
# Pmtot 6.719846686370636e+41
# Pmtot 4.1066186727848717e+43
# Pmtot 4.163950070991389e+38
# Pmtot -3.491906651451138e+41
# Pmtot 3.365645804421858e+37
# Pmtot 7.945307066948868e+41
# Pmtot 4.602807943667649e+43
# Pmtot 4.163950070991389e+38
# Pmtot -3.486284253372484e+41
# Pmtot 3.365645804421858e+37
# Pmtot 8.623231973330332e+41
# Pmtot 4.986519263511585e+43
# Pmtot 4.163950070991389e+38
# Pmtot -3.485557121403231e+41
# Pmtot 3.917240198774216e+37
# Pmtot 9.146176726596164e+41
# Pmtot 5.22966775315729e+43
# Pmtot 4.163950070991389e+38
# Pmtot -3.485291950856437e+41
# Pmtot 3.917240198774216e+37
# rundir smc_cr_lr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -5.756760380374856 0.6965143735890246 0.06947332976030031
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.4826435974565252 0.17913398492456872 0.021816820626700473
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.9338283084414812 0.866951456309004 -0.009647246417212499
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.9852451019515083 -0.07941122726364018 0.055846115951565564
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_480.hdf5
# npart_file:  [ 327137 1000000   57000    4200    2863       1]
# npart_total: [ 327137 1000000   57000    4200    2863       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.3989841763037028 0.0275315434320784 0.41799539243106903
# diskr, diskh 10 1.0
# mdisktot 1.1386028307418717e+42
# mdisktot 1.5146204711308022e+42
# mdisktot 1.5296653790063507e+42
# Pmtot 6.121598368733435e+40
# Pmtot 1.4601657957531306e+43
# Pmtot -4.614764279379299e+37
# Pmtot -3.3783334323151252e+41
# Pmtot 7.131420144588843e+37
# Pmtot 1.5942839960057935e+41
# Pmtot 2.5884492144459e+43
# Pmtot 5.296008004120823e+37
# Pmtot -3.5098807403284775e+41
# Pmtot 7.131420144588843e+37
# Pmtot 3.518506110019766e+41
# Pmtot 3.497870173883578e+43
# Pmtot 3.235925019139936e+38
# Pmtot -3.499977047326738e+41
# Pmtot 7.131420144588843e+37
# Pmtot 6.637178944383858e+41
# Pmtot 4.110061704937749e+43
# Pmtot 4.09770944543726e+38
# Pmtot -3.4918491710218126e+41
# Pmtot 7.131420144588843e+37
# Pmtot 7.918396361273581e+41
# Pmtot 4.597581521440456e+43
# Pmtot 4.09770944543726e+38
# Pmtot -3.486228235422704e+41
# Pmtot 7.131420144588843e+37
# Pmtot 8.595191642083103e+41
# Pmtot 4.979199020965053e+43
# Pmtot 4.09770944543726e+38
# Pmtot -3.48550110345345e+41
# Pmtot 7.683014538940959e+37
# Pmtot 9.111906963823954e+41
# Pmtot 5.225571878540538e+43
# Pmtot 4.09770944543726e+38
# Pmtot -3.485235932906656e+41
# Pmtot 7.683014538940959e+37
# rundir smc_cr_lr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -6.150541108268675 -0.043752327022827206 0.08654147705271159
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.49032910684969366 0.21692476228580304 0.04003445605977023
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.5449096062501206 0.8988544493231402 -0.0022961138160967247
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.9344701576206846 -0.3241875359867824 0.27885499247727197
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_490.hdf5
# npart_file:  [ 327105 1000000   57000    4200    2895       1]
# npart_total: [ 327105 1000000   57000    4200    2895       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.100355963871009 -0.4845439558306416 0.6837913169305286
# diskr, diskh 10 1.0
# mdisktot 1.1432440914631138e+42
# mdisktot 1.5193015710458893e+42
# mdisktot 1.5345354573786905e+42
# Pmtot 6.294845019696777e+40
# Pmtot 1.4618957532151507e+43
# Pmtot -3.9801377579411565e+37
# Pmtot -3.38178171204948e+41
# Pmtot 5.536874690960667e+37
# Pmtot 1.6242688289992545e+41
# Pmtot 2.5915088896428435e+43
# Pmtot 2.6497700801568156e+37
# Pmtot -3.510489315007385e+41
# Pmtot 6.0575408694206825e+37
# Pmtot 3.4999253582214476e+41
# Pmtot 3.5021416579551917e+43
# Pmtot 2.7724065750584377e+38
# Pmtot -3.499987625818549e+41
# Pmtot 6.0575408694206825e+37
# Pmtot 6.517520918825694e+41
# Pmtot 4.113116119898122e+43
# Pmtot 3.5678910015226246e+38
# Pmtot -3.492454820967751e+41
# Pmtot 6.0575408694206825e+37
# Pmtot 7.858076522311595e+41
# Pmtot 4.593541173335303e+43
# Pmtot 3.5678910015226246e+38
# Pmtot -3.486703531342522e+41
# Pmtot 6.0575408694206825e+37
# Pmtot 8.53473481982086e+41
# Pmtot 4.972118884131824e+43
# Pmtot 3.5678910015226246e+38
# Pmtot -3.485910099373437e+41
# Pmtot 6.609135263772799e+37
# Pmtot 9.049927463287402e+41
# Pmtot 5.221289270233147e+43
# Pmtot 3.5678910015226246e+38
# Pmtot -3.485644928826642e+41
# Pmtot 6.609135263772799e+37
# rundir smc_cr_lr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -6.196101211517264 -0.9579639664243438 0.2095508698159798
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.4936059758720343 0.24818196540984222 -0.030042880329569272
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.2607066240576056 1.0061620787706258 0.1149884519217744
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/smc/smc_cr_lr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [ 327076 1000000   57000    4200    2924       1]
# npart_total: [ 327076 1000000   57000    4200    2924       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.7785893994583544 0.15946258363568697 0.4695817581185882
# ...
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_470.hdf5
# npart_file:  [3183683 3500000 2000000 1000000  686527       1]
# npart_total: [3183683 3500000 2000000 1000000  686527       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_470.hdf5
# npart_file:  [3183683 3500000 2000000 1000000  686527       1]
# npart_total: [3183683 3500000 2000000 1000000  686527       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.5576029318177822 -5.142669747771683 -1.3449876779219432
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_470.hdf5
# npart_file:  [3183683 3500000 2000000 1000000  686527       1]
# npart_total: [3183683 3500000 2000000 1000000  686527       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_470.hdf5
# npart_file:  [3183683 3500000 2000000 1000000  686527       1]
# npart_total: [3183683 3500000 2000000 1000000  686527       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 1.4721294081479053 4.412872522942893 -1.1269787316119162
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_470.hdf5
# npart_file:  [3183683 3500000 2000000 1000000  686527       1]
# npart_total: [3183683 3500000 2000000 1000000  686527       1]
# flag_cooling 1
# this time 0.4699999997392297
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_470.hdf5
# npart_file:  [3183683 3500000 2000000 1000000  686527       1]
# npart_total: [3183683 3500000 2000000 1000000  686527       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -2.623041153724614 -4.527081739556301 -1.3937425413143205
# diskr, diskh 10 1.0
# mdisktot 5.18869594887881e+42
# mdisktot 8.140204934627873e+43
# mdisktot 8.393184586178878e+43
# Pmtot 7.699712516240552e+40
# Pmtot 7.504267359270234e+43
# Pmtot -2.3882499422288796e+40
# Pmtot -2.1941081413069536e+43
# Pmtot 1.5693344414599033e+40
# Pmtot 3.724140809768508e+41
# Pmtot 1.8849330453910567e+44
# Pmtot 6.136372665484008e+40
# Pmtot -4.546310726698931e+43
# Pmtot 2.7321399234664207e+40
# Pmtot 2.6020300271930516e+42
# Pmtot 3.2504043544133856e+44
# Pmtot 7.49121174933708e+42
# Pmtot -5.025537145324221e+43
# Pmtot 1.754603485025991e+41
# Pmtot 5.399907382498279e+42
# Pmtot 4.716624152780287e+44
# Pmtot 1.3466125193939865e+43
# Pmtot -4.935345849745634e+43
# Pmtot 2.5729239330887053e+41
# Pmtot 7.352601253410069e+42
# Pmtot 6.222660890644131e+44
# Pmtot 1.5681047443637208e+43
# Pmtot -4.876096317988036e+43
# Pmtot 2.780561773927947e+41
# Pmtot 8.996018527092694e+42
# Pmtot 7.735917698675807e+44
# Pmtot 1.7021086015455528e+43
# Pmtot -4.833594149020208e+43
# Pmtot 2.851293955873396e+41
# Pmtot 9.770353466466562e+42
# Pmtot 9.233515393486365e+44
# Pmtot 1.7284181151391232e+43
# Pmtot -4.801206567755434e+43
# Pmtot 2.8545187767351386e+41
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 33.7181457524496 8.370524772717836 -0.08444127735070099
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.9047908895215403 0.14629158170168735 0.37236642225294764
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.36744786983782374 -5.262667014745755 -1.3264224889396838
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -3.7910342952520275 2.404420032643825 -0.4262526812607751
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# this time 0.47999999951571226
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_480.hdf5
# npart_file:  [3177225 3500000 2000000 1000000  692985       1]
# npart_total: [3177225 3500000 2000000 1000000  692985       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.2885379487067283 -6.239081139561534 -1.1573353332611858
# diskr, diskh 10 1.0
# mdisktot 5.225615414027084e+42
# mdisktot 8.161622993628157e+43
# mdisktot 8.416990463319505e+43
# Pmtot 6.992959353780957e+40
# Pmtot 7.500006422410876e+43
# Pmtot -2.4411262956619327e+40
# Pmtot -2.1965425170903147e+43
# Pmtot 1.5314603335638965e+40
# Pmtot 3.558214547033907e+41
# Pmtot 1.8851619233256904e+44
# Pmtot 6.814024243548109e+40
# Pmtot -4.546854321120727e+43
# Pmtot 2.7063288704497214e+40
# Pmtot 2.6081446797415198e+42
# Pmtot 3.239891259526115e+44
# Pmtot 7.236802337774056e+42
# Pmtot -5.043060780389784e+43
# Pmtot 1.7723727770396727e+41
# Pmtot 5.3532395300793196e+42
# Pmtot 4.696103546231829e+44
# Pmtot 1.3335289702987212e+43
# Pmtot -4.953589051929828e+43
# Pmtot 2.602985900005321e+41
# Pmtot 7.196929819339204e+42
# Pmtot 6.184784837977972e+44
# Pmtot 1.5450269202456948e+43
# Pmtot -4.894579819659759e+43
# Pmtot 2.7998632668229984e+41
# Pmtot 8.874361909349313e+42
# Pmtot 7.685485372860643e+44
# Pmtot 1.6799615109135828e+43
# Pmtot -4.852967379775676e+43
# Pmtot 2.8788321875441068e+41
# Pmtot 9.673639184680777e+42
# Pmtot 9.167134128729052e+44
# Pmtot 1.7096012656900474e+43
# Pmtot -4.820512080004329e+43
# Pmtot 2.8828959835584147e+41
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 22.14378494364517 17.290053226250272 1.4290739211490877
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.47682398028199846 0.4696681588993419 -0.15096274407784865
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.22420610921251305 -2.777175185403889 -0.6995638687077597
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -5.011431721866992 -2.1238761388280025 -0.2328040363131596
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# this time 0.48999999929219484
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_490.hdf5
# npart_file:  [3172045 3500000 2000000 1000000  698166       1]
# npart_total: [3172045 3500000 2000000 1000000  698166       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.6046044270871218 -3.8085980474024828 -0.6133983398456335
# diskr, diskh 10 1.0
# mdisktot 5.2122358885652845e+42
# mdisktot 8.173009200883032e+43
# mdisktot 8.430055800697311e+43
# Pmtot 9.284302002130784e+40
# Pmtot 7.522760119524003e+43
# Pmtot -1.7302797637224662e+40
# Pmtot -2.188275957371903e+43
# Pmtot 1.529933566819718e+40
# Pmtot 4.10652860617051e+41
# Pmtot 1.8818673963086006e+44
# Pmtot 7.851555438714582e+40
# Pmtot -4.535490581192705e+43
# Pmtot 2.738999008556805e+40
# Pmtot 2.6802129261732705e+42
# Pmtot 3.2308358745671373e+44
# Pmtot 7.066415182894252e+42
# Pmtot -5.055621236803804e+43
# Pmtot 1.8030590662223827e+41
# Pmtot 5.3835254897944034e+42
# Pmtot 4.6766229596019535e+44
# Pmtot 1.3265955241208857e+43
# Pmtot -4.966392096651639e+43
# Pmtot 2.637590692725356e+41
# Pmtot 7.130631686112821e+42
# Pmtot 6.153753843936759e+44
# Pmtot 1.5296590748137142e+43
# Pmtot -4.90814195043847e+43
# Pmtot 2.824723279386127e+41
# Pmtot 8.794344537798995e+42
# Pmtot 7.638965751316551e+44
# Pmtot 1.6614291320585067e+43
# Pmtot -4.866791363356732e+43
# Pmtot 2.907648083266141e+41
# Pmtot 9.638046558304052e+42
# Pmtot 9.106327803995733e+44
# Pmtot 1.6958712477893632e+43
# Pmtot -4.835006102245836e+43
# Pmtot 2.9134478506582985e+41
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 6.684079869117437 16.17969923063703 -0.8145625095608128
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz 0.1273591660419545 0.5310872931824737 -0.23945005906638964
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.7474172023759873 -2.1063547172534567 -0.2979422740948807
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -1.7313573852004696 -3.976770960928555 -0.6135613016336162
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# Gvx,Gvy,Gvz -0.47745773572435873 -0.7964801773295112 -0.6283369968444216
# diskr, diskh 10 1.0
# mdisktot 5.200477547877129e+42
# mdisktot 8.17862700818698e+43
# mdisktot 8.437054439691895e+43
# Pmtot 1.2586684089784665e+41
# Pmtot 7.541119753984021e+43
# Pmtot -1.4326282248787815e+40
# Pmtot -2.1677060405383426e+43
# Pmtot 1.606793164971638e+40
# Pmtot 4.698617082221305e+41
# Pmtot 1.879438856935572e+44
# Pmtot 8.344298615982361e+40
# Pmtot -4.517422854255063e+43
# Pmtot 2.8092737117020614e+40
# Pmtot 2.7475094546912523e+42
# Pmtot 3.221363636322539e+44
# Pmtot 6.975549889578305e+42
# Pmtot -5.062052663640626e+43
# Pmtot 1.8426482948020377e+41
# Pmtot 5.4382060552082147e+42
# Pmtot 4.664209842717568e+44
# Pmtot 1.3266563163281682e+43
# Pmtot -4.973509449470469e+43
# Pmtot 2.6802641167466206e+41
# Pmtot 7.093620105795637e+42
# Pmtot 6.129193619627166e+44
# Pmtot 1.5223681135575048e+43
# Pmtot -4.915487755897914e+43
# Pmtot 2.8565609962508483e+41
# Pmtot 8.702057108631365e+42
# Pmtot 7.599172628081453e+44
# Pmtot 1.646948280277645e+43
# Pmtot -4.874848359968113e+43
# Pmtot 2.94070702105874e+41
# Pmtot 9.605548225238295e+42
# Pmtot 9.057013053396453e+44
# Pmtot 1.687914486852906e+43
# Pmtot -4.843340931053032e+43
# Pmtot 2.9490180356602417e+41
# crden [2.88279420e-13 1.67720089e-13 1.10407481e-13 7.18541686e-14
#  5.14003680e-14 3.62717288e-14 2.81106745e-14 0.00000000e+00]
# thden [8.08697217e-14 3.78150875e-14 3.00003104e-14 1.90354426e-14
#  1.06126191e-14 6.01150566e-15 3.71756112e-15 0.00000000e+00]
# mtotl [5.34604271e+43 1.43798346e+44 2.84638068e+44 4.41061249e+44
#  5.95598574e+44 7.49619113e+44 9.00066250e+44 0.00000000e+00]
# mdtot 8.398791917643071e+43
# filename /home/tkc004/samsonprogram/CRplot/rhog/rhog_bwmwmrdc29_sn450_501.pdf
