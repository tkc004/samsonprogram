# %%
from stdmodandoption import *
import plot_setup as PS
import collections
from CR_midplane_out import CR_midplane_out

def main():
    #startno=490
    #Nsnap=500
    startno=590
    Nsnap=600
    snapsep=10
    #wanted='crdenmidplane'
    wanted='stardenmidplane'
    dirdict = collections.defaultdict(dict)
    dirdict['plot1']=['m12mmhdcv','m12mcr_b_70','m12mcr_700']
    #dirdict['plot2']=['bwsmclrdc27','bwsmclrdc28','bwsmclrdc29']
    #dirdict['plot1']=['bwmwmrdc27','bwmwmrdc28','bwmwmrdc29']
    noplots=len(dirdict.keys())
    fig, ax = PS.setupfig(nrows=1, ncols=noplots,sharex=True,sharey=True)
    fmeat=''
    for i, (key,items) in enumerate(dirdict.items()):
        print 'i,key', i,key
        for runtodo in items:
            print 'runtodo', runtodo
            plotdict = CR_midplane_out(runtodo,wanted,startno,Nsnap,snapsep,fmeat)
            xnl = plotdict[wanted]['xnl'];
            ynl = plotdict[wanted]['ynl'];
            xlab = plotdict[wanted]['xlab'];
            ylab = plotdict[wanted]['ylab'];
            labelneed = plotdict[wanted]['labelneed'];
            color = plotdict[wanted]['color'];
            lsn = plotdict[wanted]['lsn'];
            filename = plotdict[wanted]['filename'];
            ptitle = plotdict[wanted]['ptitle']
            if noplots==1:
                ax.plot(xnl,ynl,label=labelneed,lw=2,ls=lsn,color=color)
            else:
                ax[i].plot(xnl,ynl,label=labelneed,lw=2,ls=lsn,color=color)
        if np.remainder(i,noplots)>0: ylab=''
        if noplots==1:
            PS.miscsetup(ax,logx=0,logy=1,xlab=xlab,ylab=ylab,title=ptitle,legendneed=1,labfs=22,legfs=12)
        else:
            PS.miscsetup(ax[i],logx=0,logy=1,xlab=xlab,ylab=ylab,title=ptitle,legendneed=1,labfs=22,legfs=12)
        
    PS.finishsave(plt,filename)


        
if __name__ == '__main__':
    main()
# Out:
# i,key 0 plot1
# runtodo m12mmhdcv
# runtodo m12mmhdcv
# rundir /m12m_mass56000/mhdcv/
# loading file : /home/tkc004//oasis/philruns///m12m_mass56000/mhdcv///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [1699578 2259972  509715       0  559795       0]
# npart_total: [13529355 17621672  4399020        0  4195491        0]
# flag_cooling 1
# this time 0.9984075952600424
# hubble 0.702
# atime 0.9984075952600424
# loading file : /home/tkc004//oasis/philruns///m12m_mass56000/mhdcv///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [1699578 2259972  509715       0  559795       0]
# npart_total: [13529355 17621672  4399020        0  4195491        0]
# flag_cooling 1
# xvcen, yvcen, zvcen -180.50775742521907 -6.551911790988749 140.34988973873595
# Gvx,Gvy,Gvz -2.5826789862433737 3.989098791881657 -3.816581463009414
# runtodo m12mcr_b_70
# runtodo m12mcr_b_70
# rundir /m12m_mass56000/cr_b_70/
# loading file : /home/tkc004//oasis/philruns///m12m_mass56000/cr_b_70///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [1820679 2209888  655978       0  426604       0]
# npart_total: [14250887 17621672  4399020        0  3474118        0]
# flag_cooling 1
# this time 0.9984075952600424
# hubble 0.702
# atime 0.9984075952600424
# loading file : /home/tkc004//oasis/philruns///m12m_mass56000/cr_b_70///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [1820679 2209888  655978       0  426604       0]
# npart_total: [14250887 17621672  4399020        0  3474118        0]
# flag_cooling 1
# xvcen, yvcen, zvcen -181.46180152972468 -9.257867686483124 140.84595589549437
# Gvx,Gvy,Gvz -6.44999477790271 4.851465968723424 -2.8029601141878766
# runtodo m12mcr_700
# runtodo m12mcr_700
# rundir /m12m_mass56000/cr_700/
# loading file : /home/tkc004//oasis/philruns///m12m_mass56000/cr_700///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [2004137 2278896  520282       0  231016       0]
# npart_total: [15883638 17621672  4399020        0  1755713        0]
# flag_cooling 1
# this time 0.9984075952600424
# hubble 0.702
# atime 0.9984075952600424
# loading file : /home/tkc004//oasis/philruns///m12m_mass56000/cr_700///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [2004137 2278896  520282       0  231016       0]
# npart_total: [15883638 17621672  4399020        0  1755713        0]
# flag_cooling 1
# xvcen, yvcen, zvcen -182.28977947747188 -8.715955895494375 141.19584563423032
# Gvx,Gvy,Gvz -7.990029032420049 1.1814429977442122 2.9387011713252273
# filename /home/tkc004/samsonprogram//CRplot/stardenmidplane/star_midplane__sn590_600.pdf
