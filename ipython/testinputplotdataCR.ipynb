# %%
import collections
from importplotfunctionsCR import *
from inputplotdataCR import inputplotdict
plotlist = ['figCRenergies_bwmwmrdc28str']
for plotneed in plotlist:
    inputplotdict[plotneed]['_plotfunction'](inputplotdict[plotneed])
# Out:
# wanted cratmult
# fmeat bwmwmrdc28str
# runtodo ['bwmwmrstreve', 'bwmwmrdc28str']
# startno 0
# Nsnap 501
# snapsep 10
# rundir mw_cr_mr_2_21_str_ll_va_eve
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 000
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_000.hdf5
# npart_file:  [3612572 3500000 2000000 1000000  258205       1]
# npart_total: [3612572 3500000 2000000 1000000  258205       1]
# flag_cooling 1
# cregy 0.0
# cregyp 0.0
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 010
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_010.hdf5
# npart_file:  [3606699 3500000 2000000 1000000  264078       1]
# npart_total: [3606699 3500000 2000000 1000000  264078       1]
# flag_cooling 1
# cregy 2.554143641664037e+55
# cregyp -3.7569122469744282e+53
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 020
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_020.hdf5
# npart_file:  [3603488 3500000 2000000 1000000  267289       1]
# npart_total: [3603488 3500000 2000000 1000000  267289       1]
# flag_cooling 1
# cregy 4.219991310123984e+55
# cregyp -1.0738151414099665e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 030
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_030.hdf5
# npart_file:  [3599905 3500000 2000000 1000000  270872       1]
# npart_total: [3599905 3500000 2000000 1000000  270872       1]
# flag_cooling 1
# cregy 5.441723682394543e+55
# cregyp -2.0551891501597152e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 040
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_040.hdf5
# npart_file:  [3595172 3500000 2000000 1000000  275605       1]
# npart_total: [3595172 3500000 2000000 1000000  275605       1]
# flag_cooling 1
# cregy 6.102052230135103e+55
# cregyp -3.272338650556921e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 050
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_050.hdf5
# npart_file:  [3589015 3500000 2000000 1000000  281762       1]
# npart_total: [3589015 3500000 2000000 1000000  281762       1]
# flag_cooling 1
# cregy 6.505969715414258e+55
# cregyp -4.571321790781038e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 060
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_060.hdf5
# npart_file:  [3581000 3500000 2000000 1000000  289777       1]
# npart_total: [3581000 3500000 2000000 1000000  289777       1]
# flag_cooling 1
# cregy 7.067632718268805e+55
# cregyp -5.991981104559757e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 070
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_070.hdf5
# npart_file:  [3569358 3500000 2000000 1000000  301419       1]
# npart_total: [3569358 3500000 2000000 1000000  301419       1]
# flag_cooling 1
# cregy 7.746791818441116e+55
# cregyp -7.493946156604665e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 080
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_080.hdf5
# npart_file:  [3557037 3500000 2000000 1000000  313740       1]
# npart_total: [3557037 3500000 2000000 1000000  313740       1]
# flag_cooling 1
# cregy 8.929027942127813e+55
# cregyp -9.134750517703296e+54
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 090
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_090.hdf5
# npart_file:  [3541509 3500000 2000000 1000000  329269       1]
# npart_total: [3541509 3500000 2000000 1000000  329269       1]
# flag_cooling 1
# cregy 1.0229206659074845e+56
# cregyp -1.0895439697443438e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 100
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_100.hdf5
# npart_file:  [3530427 3500000 2000000 1000000  340351       1]
# npart_total: [3530427 3500000 2000000 1000000  340351       1]
# flag_cooling 1
# cregy 1.1903647562959435e+56
# cregyp -1.272481170463515e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 110
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_110.hdf5
# npart_file:  [3521540 3500000 2000000 1000000  349239       1]
# npart_total: [3521540 3500000 2000000 1000000  349239       1]
# flag_cooling 1
# cregy 1.3325335001305286e+56
# cregyp -1.4539818059483672e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 120
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_120.hdf5
# npart_file:  [3513134 3500000 2000000 1000000  357645       1]
# npart_total: [3513134 3500000 2000000 1000000  357645       1]
# flag_cooling 1
# cregy 1.421024985752503e+56
# cregyp -1.6363977774319483e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 130
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_130.hdf5
# npart_file:  [3506119 3500000 2000000 1000000  364660       1]
# npart_total: [3506119 3500000 2000000 1000000  364660       1]
# flag_cooling 1
# cregy 1.457554106652206e+56
# cregyp -1.8112899590288602e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 140
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_140.hdf5
# npart_file:  [3499178 3500000 2000000 1000000  371601       1]
# npart_total: [3499178 3500000 2000000 1000000  371601       1]
# flag_cooling 1
# cregy 1.4757403274331208e+56
# cregyp -1.977977864197608e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 150
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_150.hdf5
# npart_file:  [3494213 3500000 2000000 1000000  376566       1]
# npart_total: [3494213 3500000 2000000 1000000  376566       1]
# flag_cooling 1
# cregy 1.488231119504626e+56
# cregyp -2.1526746014347234e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 160
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_160.hdf5
# npart_file:  [3489740 3500000 2000000 1000000  381039       1]
# npart_total: [3489740 3500000 2000000 1000000  381039       1]
# flag_cooling 1
# cregy 1.472245299986337e+56
# cregyp -2.3375544646482231e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 170
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_170.hdf5
# npart_file:  [3482475 3500000 2000000 1000000  388304       1]
# npart_total: [3482475 3500000 2000000 1000000  388304       1]
# flag_cooling 1
# cregy 1.4486887028849696e+56
# cregyp -2.5265636281284717e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 180
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output//snapshot_180.hdf5
# npart_file:  [3474505 3500000 2000000 1000000  396274       1]
# npart_total: [3474505 3500000 2000000 1000000  396274       1]
# flag_cooling 1
# cregy 1.440928208994822e+56
# cregyp -2.727518511747322e+55
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 190
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 200
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 210
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 220
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 230
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 240
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 250
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 260
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 270
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 280
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 290
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 300
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 310
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 320
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 330
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 340
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 350
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 360
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 370
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 380
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 390
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 400
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 410
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 420
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 430
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 440
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 450
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 460
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 470
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 480
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 490
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_eve//output/
# Nsnapstring 500
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 000
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_000.hdf5
# npart_file:  [3612572 3500000 2000000 1000000  258205       1]
# npart_total: [3612572 3500000 2000000 1000000  258205       1]
# flag_cooling 1
# cregy 0.0
# cregyp 0.0
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 010
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_010.hdf5
# npart_file:  [3605472 3500000 2000000 1000000  265305       1]
# npart_total: [3605472 3500000 2000000 1000000  265305       1]
# flag_cooling 1
# cregy 3.001677630616069e+55
# cregyp -2.44867182758179e+53
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 020
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_020.hdf5
# npart_file:  [3599988 3500000 2000000 1000000  270789       1]
# npart_total: [3599988 3500000 2000000 1000000  270789       1]
# flag_cooling 1
# cregy 6.215023948294424e+55
# cregyp -4.098823873308931e+53
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 030
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_030.hdf5
# npart_file:  [3592839 3500000 2000000 1000000  277938       1]
# npart_total: [3592839 3500000 2000000 1000000  277938       1]
# flag_cooling 1
# cregy 1.0012339289791492e+56
# cregyp -3.7471486863277003e+53
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 040
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_040.hdf5
# npart_file:  [3585025 3500000 2000000 1000000  285752       1]
# npart_total: [3585025 3500000 2000000 1000000  285752       1]
# flag_cooling 1
# cregy 1.4443776548881503e+56
# cregyp -2.59811233377147e+53
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 050
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_050.hdf5
# npart_file:  [3577103 3500000 2000000 1000000  293674       1]
# npart_total: [3577103 3500000 2000000 1000000  293674       1]
# flag_cooling 1
# cregy 1.907314445313683e+56
# cregyp 2.9603410566963087e+53
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 060
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_060.hdf5
# npart_file:  [3565643 3500000 2000000 1000000  305134       1]
# npart_total: [3565643 3500000 2000000 1000000  305134       1]
# flag_cooling 1
# cregy 2.3990163307500135e+56
# cregyp 1.5095689064172728e+54
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 070
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_070.hdf5
# npart_file:  [3547613 3500000 2000000 1000000  323164       1]
# npart_total: [3547613 3500000 2000000 1000000  323164       1]
# flag_cooling 1
# cregy 2.969420284218468e+56
# cregyp 3.744493105465226e+54
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 080
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_080.hdf5
# npart_file:  [3532923 3500000 2000000 1000000  337854       1]
# npart_total: [3532923 3500000 2000000 1000000  337854       1]
# flag_cooling 1
# cregy 3.6513467707031837e+56
# cregyp 6.058793343642236e+54
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 090
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_090.hdf5
# npart_file:  [3520295 3500000 2000000 1000000  350482       1]
# npart_total: [3520295 3500000 2000000 1000000  350482       1]
# flag_cooling 1
# cregy 4.231822782154562e+56
# cregyp 8.908819132979794e+54
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 100
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_100.hdf5
# npart_file:  [3511988 3500000 2000000 1000000  358789       1]
# npart_total: [3511988 3500000 2000000 1000000  358789       1]
# flag_cooling 1
# cregy 4.847758407416881e+56
# cregyp 1.1415481764705861e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 110
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_110.hdf5
# npart_file:  [3503216 3500000 2000000 1000000  367561       1]
# npart_total: [3503216 3500000 2000000 1000000  367561       1]
# flag_cooling 1
# cregy 5.297476242689227e+56
# cregyp 1.5544575647327961e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 120
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_120.hdf5
# npart_file:  [3496679 3500000 2000000 1000000  374098       1]
# npart_total: [3496679 3500000 2000000 1000000  374098       1]
# flag_cooling 1
# cregy 5.637748380625535e+56
# cregyp 1.7918877031085708e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 130
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_130.hdf5
# npart_file:  [3489305 3500000 2000000 1000000  381472       1]
# npart_total: [3489305 3500000 2000000 1000000  381472       1]
# flag_cooling 1
# cregy 5.89535373931195e+56
# cregyp 2.0972732228021226e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 140
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_140.hdf5
# npart_file:  [3481856 3500000 2000000 1000000  388921       1]
# npart_total: [3481856 3500000 2000000 1000000  388921       1]
# flag_cooling 1
# cregy 6.266112553465336e+56
# cregyp 2.4807794909899555e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 150
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_150.hdf5
# npart_file:  [3475654 3500000 2000000 1000000  395123       1]
# npart_total: [3475654 3500000 2000000 1000000  395123       1]
# flag_cooling 1
# cregy 6.678125557361792e+56
# cregyp 2.898348081369845e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 160
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_160.hdf5
# npart_file:  [3469058 3500000 2000000 1000000  401719       1]
# npart_total: [3469058 3500000 2000000 1000000  401719       1]
# flag_cooling 1
# cregy 7.085883714935567e+56
# cregyp 3.3426622772667917e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 170
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_170.hdf5
# npart_file:  [3462804 3500000 2000000 1000000  407973       1]
# npart_total: [3462804 3500000 2000000 1000000  407973       1]
# flag_cooling 1
# cregy 7.522238607308702e+56
# cregyp 3.793360835281727e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 180
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_180.hdf5
# npart_file:  [3456791 3500000 2000000 1000000  413986       1]
# npart_total: [3456791 3500000 2000000 1000000  413986       1]
# flag_cooling 1
# cregy 8.011514259464449e+56
# cregyp 4.224909627967746e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 190
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_190.hdf5
# npart_file:  [3449752 3500000 2000000 1000000  421025       1]
# npart_total: [3449752 3500000 2000000 1000000  421025       1]
# flag_cooling 1
# cregy 8.41690664260337e+56
# cregyp 4.7460114082760685e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 200
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_200.hdf5
# npart_file:  [3442581 3500000 2000000 1000000  428196       1]
# npart_total: [3442581 3500000 2000000 1000000  428196       1]
# flag_cooling 1
# cregy 8.842136588483728e+56
# cregyp 5.377969398892771e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 210
# havecr 6
# exceptcool 0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_210.hdf5
# npart_file:  [3435690 3500000 2000000 1000000  435087       1]
# npart_total: [3435690 3500000 2000000 1000000  435087       1]
# flag_cooling 1
# cregy 9.297389952712667e+56
# cregyp 6.007158386187078e+55
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 220
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 230
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 240
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 250
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 260
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 270
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 280
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 290
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 300
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 310
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 320
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 330
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 340
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 350
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 360
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 370
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 380
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 390
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 400
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 410
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 420
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 430
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 440
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 450
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 460
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 470
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 480
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 490
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# the_snapdir /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output/
# Nsnapstring 500
# havecr 6
# exceptcool 0
# file name is null
# KeyError
# filename /home/tkc004//samsonprogramdata/CRplot/cratmult/bwmwmrdc28str_rate.pdf
