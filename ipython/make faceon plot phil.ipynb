# %%
import samson_functions as SSF
import numpy as np
from mmfunc import runmmfromrun, runimfromrun
runtodo = 'm11gcr_b_70'; i_snap_max = Nsnap = 600; i_snap_min = Nsnap-10; ptype = 1;
theta, phi = SSF.calangLfromrun(runtodo,Nsnap,ptype,rin=5.)
print 'theta,phi', theta,phi
theta0 = int(theta/np.pi*180.); phi0 = int(phi/np.pi*180.)
print 'theta,phi (in deg)', theta0, phi0
#runmmfromrun(runtodo,i_snap_min,i_snap_max,theta0=theta0,phi0=phi0)
runimfromrun(runtodo,i_snap_max,theta0=theta0,phi0=phi0)
# Out:
# /home/tkc004/phopkins-pfh_python-ad6cabe3a84e/visualization/image_maker.py:3: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/tkc004/scratch/yt/yt-conda/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/tkc004/scratch/yt/yt-conda/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/tornado/ioloop.py", line 1073, in start
#     handler_func(fd_obj, events)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-b05a779761e4>", line 1, in <module>
#     import samson_functions as SSF
#   File "/home/tkc004/samsonprogram/tools/samson_functions.py", line 5, in <module>
#     import pylab
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/pylab.py", line 1, in <module>
#     from matplotlib.pylab import *
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/matplotlib/pylab.py", line 252, in <module>
#     from matplotlib import cbook, mlab, pyplot as plt
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg') ## this calls matplotlib without a X-windows GUI
# /home/tkc004/phopkins-pfh_python-ad6cabe3a84e/visualization/colors.py:6: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/tkc004/scratch/yt/yt-conda/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/tkc004/scratch/yt/yt-conda/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/tornado/ioloop.py", line 1073, in start
#     handler_func(fd_obj, events)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-b05a779761e4>", line 1, in <module>
#     import samson_functions as SSF
#   File "/home/tkc004/samsonprogram/tools/samson_functions.py", line 5, in <module>
#     import pylab
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/pylab.py", line 1, in <module>
#     from matplotlib.pylab import *
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/matplotlib/pylab.py", line 252, in <module>
#     from matplotlib import cbook, mlab, pyplot as plt
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/oasis/tscc/scratch/tkc004/yt/yt-conda/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg') ## this calls matplotlib without a X-windows GUI
# rundir /m11g/cr_b_70/
# loading file : /home/tkc004//oasis/philruns///m11g/cr_b_70///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [ 9154412 10307833  5379515        0  1070276        0]
# npart_total: [36779457 41013848 21232421        0  4268100        0]
# flag_cooling 1
# this time 1.0
# hubble 0.702
# loading file : /home/tkc004//oasis/philruns///m11g/cr_b_70///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [ 9154412 10307833  5379515        0  1070276        0]
# npart_total: [36779457 41013848 21232421        0  4268100        0]
# flag_cooling 1
# atime 1.0
# xvcen, yvcen, zvcen -103.22 -126.74 -127.22
# Gvx,Gvy,Gvz -13.362607975047027 -38.24842016305593 0.6778933246304959
# theta,phi 0.905644329621354 -0.29045976202937135
# theta,phi (in deg) 51 -16
# rundir /m11g/cr_b_70/
# snapdir_master /home/tkc004//oasis/philruns///m11g/cr_b_70///output/
# //
# 600
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-b05a779761e4> in <module>()
#       8 print 'theta,phi (in deg)', theta0, phi0
#       9 #runmmfromrun(runtodo,i_snap_min,i_snap_max,theta0=theta0,phi0=phi0)
# ---> 10 runimfromrun(runtodo,i_snap_max,theta0=theta0,phi0=phi0)
#
# /home/tkc004/samsonprogram/tools/mmfunc.py in runimfromrun(runtodo, snapnum, theta0, phi0)
#      60     outdir_master = '/home/tkc004/scratch/philfig/'+runtodo
#      61     TKmkdir(outdir_master)
# ---> 62     imfunc(sdir,snapnum,outdir_master=outdir_master,theta=theta0,phi=phi0)
#      63
#      64 def imfunc(sdir,snapnum,snapdir_master='',outdir_master='',snapshot_subdirectory='',theta=90.,phi=0.):
#
# /home/tkc004/samsonprogram/tools/mmfunc.py in imfunc(sdir, snapnum, snapdir_master, outdir_master, snapshot_subdirectory, theta, phi)
#      67     outdir_master=outdir_master,
#      68     snapshot_subdirectory=snapshot_subdirectory,
# ---> 69     theta=theta, phi=phi,show_gasstarxray = 'star')
#      70
#
# /home/tkc004/phopkins-pfh_python-ad6cabe3a84e/visualization/image_maker.pyc in image_maker(sdir, snapnum, snapdir_master, outdir_master, snapshot_subdirectory, theta, phi, dynrange, maxden_rescale, maxden, show_gasstarxray, add_gas_layer_to_image, set_added_layer_alpha, set_added_layer_ctable, add_extension, show_time_label, show_scale_label, filename_set_manually, do_with_colors, log_temp_wt, include_lighting, set_percent_maxden, set_percent_minden, center_on_com, center_on_bh, use_h0, cosmo, center, coordinates_cylindrical, offset, pixels, xrange, yrange, zrange, set_temp_max, set_temp_min, set_size_inches, axis_enabled, threecolor, nasa_colors, sdss_colors, use_old_extinction_routine, project_to_camera, camera_opening_angle, center_is_camera_position, camera_direction, gas_map_temperature_cuts, input_data_is_sent_directly, m_all, x_all, y_all, z_all, c_all, h_all, zm_all, gas_u, gas_rho, gas_hsml, gas_numh, gas_nume, gas_metallicity, gas_mass, gas_x, gas_y, gas_z, time, invert_colors, spin_movie, scattered_fraction, min_stellar_age, h_rescale_factor, h_max, angle_to_rotate_image, projection_vector_x, projection_vector_y, projection_vector_z, BAND_IDS, set_f_saturated, dust_to_gas_ratio_rescale, add_temperature_weights)
#     733         m_all, x_all, y_all, z_all, c_all, h_all, zm_all, time = load_snapshot_brick(ptypes, \
#     734             snapdir, snapnum, h0=use_h0, cosmological=cosmo, filename_prefix=sdir,\
# --> 735             skip_bh=cosmo, do_xray=do_xray, four_char=0, use_rundir=0, full_gas_set=0);
#     736         h_all *= 1.25;
#     737
#
# /home/tkc004/phopkins-pfh_python-ad6cabe3a84e/visualization/image_maker.pyc in load_snapshot_brick(ptypes, snapdir, snapnum, h0, cosmological, skip_bh, do_xray, four_char, use_rundir, full_gas_set, filename_prefix)
#      51     print snapnum
#      52     ppp_head=gadget.readsnap(snapdir,snapnum,0,h0=h0,cosmological=cosmological,skip_bh=skip_bh,header_only=1)
# ---> 53     time=ppp_head['time']
#      54     if (full_gas_set==1):
#      55         ## here it will just return the entire gas 'brick'
#
# KeyError: 'time'
