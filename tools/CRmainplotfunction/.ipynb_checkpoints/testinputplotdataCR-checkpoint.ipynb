# %%
import collections
from importplotfunctionsCR import *
from inputplotdataCR import inputplotdict
plotlist = ['figCRgasmid_smcgas','figCRgasmid_mwgas']
for plotneed in plotlist:
    inputplotdict[plotneed]['_plotfunction'](inputplotdict[plotneed])
# Out:
# wanted crecumr
# fmeat bwmwmrdc28str
# runtodo ['bwmwmrdc0', 'bwmwmrdc27', 'bwmwmrdc28', 'bwmwmrdc29', 'bwmwmrstr', 'bwmwmrdc28mhd', 'bwmwmrdc28str']
# rundir mw_cr_mr_dc0_2_21
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc0_2_21//output//snapshot_000.hdf5
# npart_file:  [3664110 3500000 2000000 1000000  205905       1]
# npart_total: [3664110 3500000 2000000 1000000  205905       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc0_2_21//output//snapshot_500.hdf5
# npart_file:  [3266968 3500000 2000000 1000000  603095       1]
# npart_total: [3266968 3500000 2000000 1000000  603095       1]
# flag_cooling 1
# Esncr 1.0681582774695206e+57
# rundir mw_cr_mr_dc0_2_21
# labelneed,newlabel Advection Advection
# rundir mw_cr_mr_dc0_2_21
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc0_2_21//output//snapshot_500.hdf5
# npart_file:  [3266968 3500000 2000000 1000000  603095       1]
# npart_total: [3266968 3500000 2000000 1000000  603095       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc0_2_21//output//snapshot_500.hdf5
# npart_file:  [3266968 3500000 2000000 1000000  603095       1]
# npart_total: [3266968 3500000 2000000 1000000  603095       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_dc0_2_21
# CR energy in erg 1.0423153433604468e+56
# rundir mw_cr_mr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc27_2_21_M1_c500//output//snapshot_000.hdf5
# npart_file:  [3664110 3500000 2000000 1000000  205905       1]
# npart_total: [3664110 3500000 2000000 1000000  205905       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [3366562 3500000 2000000 1000000  503524       1]
# npart_total: [3366562 3500000 2000000 1000000  503524       1]
# flag_cooling 1
# Esncr 8.01839301976344e+56
# rundir mw_cr_mr_dc27_2_21_M1_c500
# labelneed,newlabel $\kappa$=3e27 $\kappa$=3e27
# rundir mw_cr_mr_dc27_2_21_M1_c500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [3366562 3500000 2000000 1000000  503524       1]
# npart_total: [3366562 3500000 2000000 1000000  503524       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc27_2_21_M1_c500//output//snapshot_500.hdf5
# npart_file:  [3366562 3500000 2000000 1000000  503524       1]
# npart_total: [3366562 3500000 2000000 1000000  503524       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_dc27_2_21_M1_c500
# CR energy in erg 9.333522722494239e+56
# rundir mw_cr_mr_dc28_2_21_M1_c1000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_c1000//output//snapshot_000.hdf5
# npart_file:  [3664110 3500000 2000000 1000000  205905       1]
# npart_total: [3664110 3500000 2000000 1000000  205905       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_c1000//output//snapshot_500.hdf5
# npart_file:  [3232779 3500000 2000000 1000000  637386       1]
# npart_total: [3232779 3500000 2000000 1000000  637386       1]
# flag_cooling 1
# Esncr 1.158571504893309e+57
# rundir mw_cr_mr_dc28_2_21_M1_c1000
# labelneed,newlabel $\kappa$=3e28 $\kappa$=3e28
# rundir mw_cr_mr_dc28_2_21_M1_c1000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_c1000//output//snapshot_500.hdf5
# npart_file:  [3232779 3500000 2000000 1000000  637386       1]
# npart_total: [3232779 3500000 2000000 1000000  637386       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_c1000//output//snapshot_500.hdf5
# npart_file:  [3232779 3500000 2000000 1000000  637386       1]
# npart_total: [3232779 3500000 2000000 1000000  637386       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_dc28_2_21_M1_c1000
# CR energy in erg 1.4902868971011184e+57
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_000.hdf5
# npart_file:  [3664110 3500000 2000000 1000000  205905       1]
# npart_total: [3664110 3500000 2000000 1000000  205905       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# Esncr 1.3306464223187786e+57
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# labelneed,newlabel $\kappa$=3e29 $\kappa$=3e29
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc29_2_21_M1_c2000//output//snapshot_500.hdf5
# npart_file:  [3167376 3500000 2000000 1000000  702835       1]
# npart_total: [3167376 3500000 2000000 1000000  702835       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_dc29_2_21_M1_c2000
# CR energy in erg 9.291963421045296e+56
# rundir mw_cr_mr_2_21_str_ll_va_evepts
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_evepts//output//snapshot_000.hdf5
# npart_file:  [3612572 3500000 2000000 1000000  258205       1]
# npart_total: [3612572 3500000 2000000 1000000  258205       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_evepts//output//snapshot_500.hdf5
# npart_file:  [3292526 3500000 2000000 1000000  578269       1]
# npart_total: [3292526 3500000 2000000 1000000  578269       1]
# flag_cooling 1
# Esncr 8.69094657758538e+56
# rundir mw_cr_mr_2_21_str_ll_va_evepts
# labelneed,newlabel MHD
# Streaming MHD          Streaming
# rundir mw_cr_mr_2_21_str_ll_va_evepts
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_evepts//output//snapshot_500.hdf5
# npart_file:  [3292526 3500000 2000000 1000000  578269       1]
# npart_total: [3292526 3500000 2000000 1000000  578269       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_2_21_str_ll_va_evepts//output//snapshot_500.hdf5
# npart_file:  [3292526 3500000 2000000 1000000  578269       1]
# npart_total: [3292526 3500000 2000000 1000000  578269       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_2_21_str_ll_va_evepts
# CR energy in erg 1.2390096592368783e+56
# rundir mw_cr_mr_dc28_2_21_M1_mhd_c1000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_mhd_c1000//output//snapshot_000.hdf5
# npart_file:  [3664110 3500000 2000000 1000000  205905       1]
# npart_total: [3664110 3500000 2000000 1000000  205905       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_mhd_c1000//output//snapshot_500.hdf5
# npart_file:  [3278743 3500000 2000000 1000000  592034       1]
# npart_total: [3278743 3500000 2000000 1000000  592034       1]
# flag_cooling 1
# Esncr 1.0414551693745863e+57
# rundir mw_cr_mr_dc28_2_21_M1_mhd_c1000
# labelneed,newlabel MHD $\kappa$=3e28 MHD $\kappa$=3e28
# rundir mw_cr_mr_dc28_2_21_M1_mhd_c1000
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_mhd_c1000//output//snapshot_500.hdf5
# npart_file:  [3278743 3500000 2000000 1000000  592034       1]
# npart_total: [3278743 3500000 2000000 1000000  592034       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_M1_mhd_c1000//output//snapshot_500.hdf5
# npart_file:  [3278743 3500000 2000000 1000000  592034       1]
# npart_total: [3278743 3500000 2000000 1000000  592034       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_dc28_2_21_M1_mhd_c1000
# CR energy in erg 1.3003395500921807e+57
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_000.hdf5
# npart_file:  [3612572 3500000 2000000 1000000  258205       1]
# npart_total: [3612572 3500000 2000000 1000000  258205       1]
# flag_cooling 1
# Nsnapstring 500
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_500.hdf5
# npart_file:  [3275602 3500000 2000000 1000000  595175       1]
# npart_total: [3275602 3500000 2000000 1000000  595175       1]
# flag_cooling 1
# Esncr 9.132110907144695e+56
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# labelneed,newlabel MHD $\kappa$=3e28
# Streaming MHD $\kappa$=3e28       Streaming
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_500.hdf5
# npart_file:  [3275602 3500000 2000000 1000000  595175       1]
# npart_total: [3275602 3500000 2000000 1000000  595175       1]
# flag_cooling 1
# this time 0.5
# hubble 1.0
# loading file : /home/tkc004/oasis/bw/mw/mw_cr_mr_dc28_2_21_str_ll_va_eve//output//snapshot_500.hdf5
# npart_file:  [3275602 3500000 2000000 1000000  595175       1]
# npart_total: [3275602 3500000 2000000 1000000  595175       1]
# flag_cooling 1
# xvcen, yvcen, zvcen 0 0 0
# rundir mw_cr_mr_dc28_2_21_str_ll_va_eve
# CR energy in erg 1.3853000629185462e+57
# filename /home/tkc004//samsonprogramdata/CRplot/crecumr/crecumr_bwmwmrdc28str_sn490_500.pdf
