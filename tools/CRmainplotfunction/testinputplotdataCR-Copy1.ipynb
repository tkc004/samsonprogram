# %%
import collections
from importplotfunctionsCR import *
from inputplotdataCR import inputplotdict
plotlist = ['figsfr_m12mhr']
for plotneed in plotlist:
    inputplotdict[plotneed]['_plotfunction'](inputplotdict[plotneed])
# Out:
# runtodo m12mmhdcvhr
# rundir /m12m_mass7000/mhdcv/
# set initial time
# the_snapdir /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output/
# Nsnapstring 580
# havecr 0
# withinRv 1
# cosmo 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [7383672 8639700  721555       0 1753209       0]
# npart_total: [113624854 140876456  10063684         0  28411831         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [7383672 8639700  721555       0 1753209       0]
# npart_total: [113624854 140876456  10063684         0  28411831         0]
# flag_cooling 1
# timeneed 0.9824840917626294
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [7383672 8639700  721555       0 1753209       0]
# npart_total: [113624854 140876456  10063684         0  28411831         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [7383672 8639700  721555       0 1753209       0]
# npart_total: [113624854 140876456  10063684         0  28411831         0]
# flag_cooling 1
# rundir /m12m_mass7000/mhdcv/
# set initial time
# the_snapdir /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output/
# Nsnapstring 590
# havecr 0
# withinRv 1
# cosmo 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [8096191 8578753 1189278       0 1515513       0]
# npart_total: [113192568 140876456  10063684         0  28973716         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [8096191 8578753 1189278       0 1515513       0]
# npart_total: [113192568 140876456  10063684         0  28973716         0]
# flag_cooling 1
# timeneed 0.9984075952600424
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [8096191 8578753 1189278       0 1515513       0]
# npart_total: [113192568 140876456  10063684         0  28973716         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [8096191 8578753 1189278       0 1515513       0]
# npart_total: [113192568 140876456  10063684         0  28973716         0]
# flag_cooling 1
# rundir /m12m_mass7000/mhdcv/
# set initial time
# the_snapdir /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output/
# Nsnapstring 600
# havecr 0
# withinRv 1
# cosmo 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [4256397 9151905 1511331       0 2552816       0]
# npart_total: [113153381 140876456  10063684         0  29025856         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [4256397 9151905 1511331       0 2552816       0]
# npart_total: [113153381 140876456  10063684         0  29025856         0]
# flag_cooling 1
# timeneed 1.0
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [4256397 9151905 1511331       0 2552816       0]
# npart_total: [113153381 140876456  10063684         0  29025856         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/mhdcv///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [4256397 9151905 1511331       0 2552816       0]
# npart_total: [113153381 140876456  10063684         0  29025856         0]
# flag_cooling 1
# nsml [1.46647302e+11 3.66517102e+09 3.75172524e+08]
# avesfrl [16.4280793  16.90418156]
# Lsfr [5.69778154e+44 5.86290899e+44]
# timel [1.35536339e+10 1.37767379e+10 1.37989320e+10]
# labelneed MHD no CR
# runtodo m12mcr_700hr
# rundir /m12m_mass7000/cr_700/
# set initial time
# the_snapdir /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output/
# Nsnapstring 580
# havecr 1
# withinRv 1
# cosmo 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [8071899 9947205  681351       0  460861       0]
# npart_total: [132936597 140876456  10063684         0   7967612         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [8071899 9947205  681351       0  460861       0]
# npart_total: [132936597 140876456  10063684         0   7967612         0]
# flag_cooling 1
# timeneed 0.9824840917626294
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [8071899 9947205  681351       0  460861       0]
# npart_total: [132936597 140876456  10063684         0   7967612         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_580/snapshot_580.0.hdf5
# npart_file:  [8071899 9947205  681351       0  460861       0]
# npart_total: [132936597 140876456  10063684         0   7967612         0]
# flag_cooling 1
# Lgcal 1.3739296197740434e+40
# rundir /m12m_mass7000/cr_700/
# set initial time
# the_snapdir /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output/
# Nsnapstring 590
# havecr 1
# withinRv 1
# cosmo 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [7858272 9349728  738373       0  492359       0]
# npart_total: [132841760 140876456  10063684         0   8062702         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [7858272 9349728  738373       0  492359       0]
# npart_total: [132841760 140876456  10063684         0   8062702         0]
# flag_cooling 1
# timeneed 0.9984075952600424
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [7858272 9349728  738373       0  492359       0]
# npart_total: [132841760 140876456  10063684         0   8062702         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_590/snapshot_590.0.hdf5
# npart_file:  [7858272 9349728  738373       0  492359       0]
# npart_total: [132841760 140876456  10063684         0   8062702         0]
# flag_cooling 1
# Lgcal 8.938134730199009e+39
# rundir /m12m_mass7000/cr_700/
# set initial time
# the_snapdir /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output/
# Nsnapstring 600
# havecr 1
# withinRv 1
# cosmo 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [8530666 9355240  399118       0  550035       0]
# npart_total: [132832344 140876456  10063684         0   8072148         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [8530666 9355240  399118       0  550035       0]
# npart_total: [132832344 140876456  10063684         0   8072148         0]
# flag_cooling 1
# timeneed 1.0
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [8530666 9355240  399118       0  550035       0]
# npart_total: [132832344 140876456  10063684         0   8072148         0]
# flag_cooling 1
# loading file : /home/tkc004//oasis/philruns///m12m_mass7000/cr_700///output//snapdir_600/snapshot_600.0.hdf5
# npart_file:  [8530666 9355240  399118       0  550035       0]
# npart_total: [132832344 140876456  10063684         0   8072148         0]
# flag_cooling 1
# Lgcal 7.799090025796682e+39
# nsml [3.53151120e+10 6.33920366e+08 7.18161840e+07]
# avesfrl [2.84136647 3.23582815]
# Lsfr [9.85476460e+43 1.12228834e+44]
# timel [1.35536339e+10 1.37767379e+10 1.37989320e+10]
# labelneed MHD $\kappa$=3e29
# Saving  /home/tkc004//samsonprogramdata/CRplot/dirsfr/sfrsnap_m12mcr_700hr.pdf
