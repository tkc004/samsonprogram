# %%
import collections
from inputplotdataISM import inputplotdict
plotlist = [
            'figintrhogfrompardist_m12ihr0_25kpcr9_usekez',
            'figintrhogfrompardist_m12fhr0_25kpcr9_usekez',
            'figintrhogfrompardist_m12mhr0_25kpcr9_usekez',
            'figintrhogfrompardist_m12ihr0_25kpcr9',
            'figintrhogfrompardist_m12fhr0_25kpcr9',
            'figintrhogfrompardist_m12mhr0_25kpcr9',
            'figintrhogfrompardist_m12ihr0_25kpc_usekez',
            'figintrhogfrompardist_m12fhr0_25kpc_usekez',
            'figintrhogfrompardist_m12mhr0_25kpc_usekez',
            'figintrhogfrompardist_m12ihr0_25kpc',
            'figintrhogfrompardist_m12fhr0_25kpc',
            'figintrhogfrompardist_m12mhr0_25kpc',
           'figintrhogfrompardist_m12ihr0_5kpcr9',
           'figintrhogfrompardist_m12fhr0_5kpcr9',
           'figintrhogfrompardist_m12mhr0_5kpcr9',
           'figintrhogfrompardist_m12ihr2kpc',
           'figintrhogfrompardist_m12fhr2kpc',
           'figintrhogfrompardist_m12mhr2kpc',
           'figintrhogfrompardist_m12mhr2kpc_usekez',
           'figintrhogfrompardist_m12fhr2kpc_usekez',
           'figintrhogfrompardist_m12ihr2kpc_ueskez',
           'figintrhogfrompardist_m12ihr0_5kpc_usekez',
           'figintrhogfrompardist_m12fhr0_5kpc_usekez',
           'figintrhogfrompardist_m12mhr0_5kpc_usekez',
            'figintrhogfrompardist_m12ihr1kpc_usekez',
            'figintrhogfrompardist_m12fhr1kpc_usekez',
            'figintrhogfrompardist_m12mhr1kpc_usekez',
           ]
for plotneed in plotlist:
    inputplotdict[plotneed]['_plotfunction'](inputplotdict[plotneed])
# Out:
# noplots 2
# runtodo m12imhdcvhr
# wanted pz
# runtodo m12imhdcvhr
# rundir /m12i_mass7000_MHDCR_tkFIX/mhdcv/
# rundir /m12i_mass7000_MHDCR_tkFIX/mhdcv/
# /home/tkc004/samsonprogram/tools/samson_functions.py:10184: RuntimeWarning: invalid value encountered in divide
#   pkezgrid = kezgrid/volgrid*2.0
# rundir /m12i_mass7000_MHDCR_tkFIX/mhdcv/
# rundir /m12i_mass7000_MHDCR_tkFIX/mhdcv/
# rundir /m12i_mass7000_MHDCR_tkFIX/mhdcv/
# rundir /m12i_mass7000_MHDCR_tkFIX/mhdcv/
# filename /home/tkc004//samsonprogramdata/CRplot/crdenz/rhogpzfrompar_pz_m12igrid0_25kpc_r9kpc_usekez_sn580_600.pdf
# runtodo m12icr_700hr
# wanted pz
# runtodo m12icr_700hr
# rundir /m12i_mass7000_MHDCR_tkFIX/cr_700/
# rundir /m12i_mass7000_MHDCR_tkFIX/cr_700/
# rundir /m12i_mass7000_MHDCR_tkFIX/cr_700/
# rundir /m12i_mass7000_MHDCR_tkFIX/cr_700/
# rundir /m12i_mass7000_MHDCR_tkFIX/cr_700/
# rundir /m12i_mass7000_MHDCR_tkFIX/cr_700/
# ...
