# %%
import numpy as np

xlist = np.linspace(0,10,num=10)
ylist = np.linspace(10,20,num=20)
zlist = np.linspace(20,30,num=30)
xl, yl, zl = np.meshgrid(xlist,ylist,zlist)

# %%
xl
# Out:
# array([[[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.11111111,  1.11111111,  1.11111111, ...,  1.11111111,
#           1.11111111,  1.11111111],
#         [ 2.22222222,  2.22222222,  2.22222222, ...,  2.22222222,
#           2.22222222,  2.22222222],
#         ...,
#         [ 7.77777778,  7.77777778,  7.77777778, ...,  7.77777778,
#           7.77777778,  7.77777778],
#         [ 8.88888889,  8.88888889,  8.88888889, ...,  8.88888889,
#           8.88888889,  8.88888889],
#         [10.        , 10.        , 10.        , ..., 10.        ,
#          10.        , 10.        ]],
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.11111111,  1.11111111,  1.11111111, ...,  1.11111111,
#           1.11111111,  1.11111111],
#         [ 2.22222222,  2.22222222,  2.22222222, ...,  2.22222222,
#           2.22222222,  2.22222222],
#         ...,
# ...

# %%
xl.ravel().reshape((len(xlist),len(ylist),len(zlist)))
# Out:
# array([[[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.11111111,  1.11111111,  1.11111111, ...,  1.11111111,
#           1.11111111,  1.11111111],
#         [ 2.22222222,  2.22222222,  2.22222222, ...,  2.22222222,
#           2.22222222,  2.22222222],
#         ...,
#         [ 7.77777778,  7.77777778,  7.77777778, ...,  7.77777778,
#           7.77777778,  7.77777778],
#         [ 8.88888889,  8.88888889,  8.88888889, ...,  8.88888889,
#           8.88888889,  8.88888889],
#         [10.        , 10.        , 10.        , ..., 10.        ,
#          10.        , 10.        ]],
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.11111111,  1.11111111,  1.11111111, ...,  1.11111111,
#           1.11111111,  1.11111111],
#         [ 2.22222222,  2.22222222,  2.22222222, ...,  2.22222222,
#           2.22222222,  2.22222222],
#         ...,
# ...
