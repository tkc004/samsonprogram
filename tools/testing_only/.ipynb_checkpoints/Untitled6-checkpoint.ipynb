# %%
import numpy as np
import samson_functions as SSF
x=[20,0,0]
y=[0,0,0]
z=[0,0,0]
weights=[1,1,1]
xlist=ylist=zlist=np.linspace(0,1,num=10)
meshx,meshy,meshz,meshweights = SSF.depositandcor3d(x,y,z,weights,xlist,ylist,zlist)
#np.histogramdd(np.vstack((x, y, z)), bins=(xlist, ylist, zlist),weights=weights)

# %%
print meshx,meshy,meshz,meshweights
# Out:
# [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#  0.05555556 0.05555556 0.05555556 0.16666667 0.16666667 0.16666667
#  0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667
#  0.27777778 0.27777778 0.27777778 0.27777778 0.27777778 0.27777778
#  0.27777778 0.27777778 0.27777778 0.38888889 0.38888889 0.38888889
#  0.38888889 0.38888889 0.38888889 0.38888889 0.38888889 0.38888889
#  0.5        0.5        0.5        0.5        0.5        0.5
#  0.5        0.5        0.5        0.61111111 0.61111111 0.61111111
#  0.61111111 0.61111111 0.61111111 0.61111111 0.61111111 0.61111111
#  0.72222222 0.72222222 0.72222222 0.72222222 0.72222222 0.72222222
#  0.72222222 0.72222222 0.72222222 0.83333333 0.83333333 0.83333333
#  0.83333333 0.83333333 0.83333333 0.83333333 0.83333333 0.83333333
#  0.94444444 0.94444444 0.94444444 0.94444444 0.94444444 0.94444444
#  0.94444444 0.94444444 0.94444444 0.05555556 0.05555556 0.05555556
# ...
